# %% [markdown]
# # Predictive Model Training

# %% [markdown]
# ## Setup

# %%
# !cd src; poetry install
# Out:
# Creating virtualenv cryptotrading-5LOnqLwL-py3.10 in /home/miles/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
# ...
#
# Package operations: 68 installs, 1 update, 0 removals
#
#   • Installing idna (3.10): Pending...
#   • Installing mdurl (0.1.2): Pending...
#   • Installing sniffio (1.3.1): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing sniffio (1.3.1): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing mdurl (0.1.2): Installing...
#   • Installing sniffio (1.3.1): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing sniffio (1.3.1): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing mdurl (0.1.2)
#   • Installing sniffio (1.3.1): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing typing-extensions (4.12.2): Pending...
#   • Installing sniffio (1.3.1): Installing...
# ...

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
add_modules = ["src"]
for m in add_modules:
    if m not in sys.path:
        sys.path.append(m)
        print(f"Added {m} to sys path")
# Out:
# Added src to sys path

# %%
import cryptotrading
